# %% [markdown]
# <a href="https://colab.research.google.com/github/Ruethaichanok-kas68/y/blob/main/Copy_of_string_and_list.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # String and List in Python <a href="https://colab.research.google.com/github/ro-witthawin/TBS-BI303-2026/blob/main/Day02/string_and_list.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# In this notebook, you will learn how to work with two very common Python data types: **strings** and **lists**.
#
# Topics:
# - Creating strings
# - String indexing and slicing
# - Useful string methods
# - Creating lists
# - List indexing and slicing
# - Adding, updating, and removing list items
# - Looping through strings and lists
# - Practice exercises

# %% [markdown]
# ## 1. What Is a String?
#
# A **string** is text data in Python. You can create a string by putting text inside single quotes (`'...'`) or double quotes (`"..."`).

# %%
# Creating strings
course_name = "Business Intelligence"
student_name = 'Witthawin'

print(course_name)
print(student_name)
print(type(course_name))
# Out:
# Business Intelligence
# Witthawin
# <class 'str'>

# %%
# More string examples
city = "Bangkok"
country = "Thailand"
empty_text = ""

print(city)
print(country)
print(empty_text)
print(type(empty_text))

# %% [markdown]
# ## 2. String Concatenation
#
# You can join strings together using the `+` operator. This is called **concatenation**.

# %%
first_name = "John"
last_name = "Smith"

full_name = first_name + " " + last_name
print(full_name)

# %%
# More concatenation examples
department = "BI"
course_code = "303"

print(department + course_code)
print(department + " " + course_code)
print("Welcome to " + department + course_code + "!")

# %% [markdown]
# ## 3. String Indexing
#
# Each character in a string has an index number.
#
# Important notes:
# - Python starts counting from `0`.
# - Negative indexes count from the end of the string.
#
# Example: `Python`
#
# | Character | P | y | t | h | o | n |
# |----------|---|---|---|---|---|---|
# | Index    | 0 | 1 | 2 | 3 | 4 | 5 |
# | Negative | -6 | -5 | -4 | -3 | -2 | -1 |

# %%
word = "Python"

print(word[0])   # First character
print(word[1])   # Second character
print(word[-1])  # Last character
print(word[-2])  # Second last character

# %%
# More indexing examples
student_id = "BI303-2026"

print(student_id[0])
print(student_id[2])
print(student_id[-4])
print(student_id[-1])

# %% [markdown]
# ## 4. String Slicing
#
# Slicing is used to get part of a string.
#
# Syntax:
#
# ```python
# string[start:stop]
# ```
#
# The `start` index is included, but the `stop` index is not included.

# %%
text = "Data Science"

print(text[0:4])   # Characters from index 0 to 3
print(text[5:12])  # Characters from index 5 to 11
print(text[:4])    # From the beginning to index 3
print(text[5:])    # From index 5 to the end

# %%
# More slicing examples
student_id = "BI303-2026"

print(student_id[0:2])   # BI
print(student_id[2:5])   # 303
print(student_id[6:])    # 2026
print(student_id[::-1])  # Reverse the string

# %% [markdown]
# ## 5. Useful String Methods
#
# A **method** is an action that belongs to an object. String methods help us clean, search, and transform text.
#
# | Method | Description |
# |--------|-------------|
# | `.upper()` | Convert text to uppercase |
# | `.lower()` | Convert text to lowercase |
# | `.strip()` | Remove spaces from the beginning and end |
# | `.replace(old, new)` | Replace part of the text |
# | `.count(value)` | Count how many times a value appears |
# | `.find(value)` | Find the index of a value |

# %%
message = "  Python is fun. Python is useful.  "

print(message.upper())
print(message.lower())
print(message.strip())
print(message.replace("Python", "Programming"))
print(message.count("Python"))
print(message.find("fun"))

# %%
# More string method examples
email = "  student@example.com  "
clean_email = email.strip().lower()

print(clean_email)
print(clean_email.startswith("student"))
print(clean_email.endswith(".com"))
print(clean_email.replace("example", "tbs"))

# %% [markdown]
# ## Practice Exercise 1
#
# Create a variable called `my_name` and store your name in it.
#
# Then print:
# - Your name in uppercase
# - Your name in lowercase
# - The first character of your name
# - The last character of your name

# %%
# TODO: Write your answer here
my_name = ""
# Example:
# print(my_name.upper())

# %%
my_name = "Ruethaichanok Kasatecharoen"
print(my_name.upper())
print(my_name.lower())
print(my_name[0])
print(my_name[-1])
# Out:
# RUETHAICHANOK KASATECHAROEN
# ruethaichanok kasatecharoen
# R
# n

# %%
my_firstname = str(input("Enter your first name: "))
my_lastname = str(input("Enter your last name: "))
print((my_firstname + " " + my_lastname).upper())
print((my_firstname + " " + my_lastname).lower())
print((my_firstname + " " + my_lastname)[0])
print((my_firstname + " " + my_lastname)[-1])
# Out:
# Enter your first name: Michael
# Enter your last name: Jackson
# MICHAEL JACKSON
# michael jackson
# M
# n

# %% [markdown]
# ## Practice Exercise 2
#
# You are given a messy product name.
#
# ```python
# product_name = "  wireless mouse  "
# ```
#
# Write code to:
# - Remove spaces from the beginning and end
# - Convert the product name to title case
# - Replace `mouse` with `keyboard`
# - Print the final result

# %%
product_name = "  wireless mouse  "

# TODO: Write your answer here

# %%
product_name = "  wireless mouse  "
product_name = product_name.strip()
product_name = product_name[0].upper() + product_name[1:]
product_name = product_name.replace("mouse", "keyboard")
print(product_name)
# Out:
# Wireless keyboard

# %%
name = "  witthawin sripheanpol "
name = name.strip()
name = name[0].upper() + name[1:9] + " " + name[10].upper() + name[11:]
print(name)
# Out:
# Witthawin Sripheanpol

# %% [markdown]
# ## 6. f-Strings
#
# An **f-string** is a simple way to put variables inside a string. Put `f` before the opening quote and place variables inside `{}`.

# %%
# mai oak koh sorb
name = "Maya"
score = 87

print(f"Student name: {name}")
print(f"Score: {score}")
print(f"{name} got {score} points in the exam.")
# Out:
# Student name: Maya
# Score: 87
# Maya got 87 points in the exam.

# %%
# More f-string examples
product = "Notebook"
price = 49.9
quantity = 3

print(f"Product: {product}")
print(f"Total price: {price * quantity}")
print(f"Total price: {price * quantity:.2f} baht")

# %% [markdown]
# ## 7. Converting Values to Strings with `str()`
#
# The `str()` function converts a value into a string.
#
# This is useful when you want to combine text with numbers or other data types using `+`.

# %%
age = 20
score = 95.5

print(str(age))
print(type(str(age)))

message = "Age: " + str(age) + ", Score: " + str(score)
print(message)
# Out:
# 20
# <class 'str'>
# Age: 20, Score: 95.5

# %% [markdown]
# Without `str()`, Python will show an error when you try to join a string and a number using `+`.

# %%
# This works because age is converted to a string first
age = 20
print("I am " + str(age) + " years old.")

# %%
# More str() examples
order_id = 105
is_paid = True

print("Order ID: " + str(order_id))
print("Payment status: " + str(is_paid))
print("Data type after conversion:", type(str(is_paid)))

# %% [markdown]
# ## 8. What Is a List?
#
# A **list** is used to store multiple values in one variable. Lists are written with square brackets `[]`.
#
# A list can contain strings, numbers, booleans, or even mixed data types.

# %%
# Creating lists
fruits = ["apple", "banana", "orange"]
scores = [80, 75, 92, 88]
mixed_data = ["Alice", 20, True]

print(fruits)
print(scores)
print(mixed_data)
print(type(fruits))
# Out:
# ['apple', 'banana', 'orange']
# [80, 75, 92, 88]
# ['Alice', 20, True]
# <class 'list'>

# %%
# More list examples
subjects = ["Python", "SQL", "Dashboard"]
prices = [120.5, 99.0, 250.75]
flags = [True, False, True]

print(subjects)
print(prices)
print(flags)

# %% [markdown]
# ## 9. List Indexing
#
# List indexing works like string indexing. The first item is at index `0`.

# %%
fruits = ["apple", "banana", "orange", "mango"]

print(fruits[0])   # First item
print(fruits[2])   # Third item
print(fruits[-1])  # Last item

# %%
# More list indexing examples
subjects = ["Python", "SQL", "Dashboard", "Excel"]

print(subjects[0])
print(subjects[3])
print(subjects[-1])
print(subjects[-3])

# %% [markdown]
# ## 10. List Slicing
#
# You can use slicing to get part of a list.

# %%
numbers = [10, 20, 30, 40, 50, 60]

print(numbers[0:3])  # First three items
print(numbers[2:5])  # Items from index 2 to 4
print(numbers[:4])   # From the beginning to index 3
print(numbers[3:])   # From index 3 to the end

# %%
# More list slicing examples
subjects = ["Python", "SQL", "Dashboard", "Excel", "Statistics"]

print(subjects[1:4])
print(subjects[:2])
print(subjects[2:])
print(subjects[::-1])

# %% [markdown]
# ## 11. Updating List Items
#
# Lists are **mutable**, which means you can change their values after creating them.

# %%
fruits = ["apple", "banana", "orange"]

fruits[1] = "grape"

print(fruits)
# Out:
# ['apple', 'grape', 'orange']

# %%
# More updating examples
subjects = ["Python", "SQL", "Dashboard"]

subjects[2] = "Power BI"
print(subjects)

subjects[0:2] = ["Basic Python", "Database"]
print(subjects)
# Out:
# ['Python', 'SQL', 'Power BI']
# ['Basic Python', 'Database', 'Power BI']

# %% [markdown]
# ## 12. Adding Items to a List
#
# Common methods for adding items:
#
# | Method | Description |
# |--------|-------------|
# | `.append(value)` | Add one item to the end |
# | `.insert(index, value)` | Add one item at a specific position |
# | `.extend(list)` | Add multiple items from another list |

# %%
fruits = ["apple", "banana"]

fruits.append("orange")
print(fruits)

fruits.insert(1, "mango")
print(fruits)

fruits.extend(["grape", "melon"])
print(fruits)
# Out:
# ['apple', 'banana', 'orange']
# ['apple', 'mango', 'banana', 'orange']
# ['apple', 'mango', 'banana', 'orange', 'grape', 'melon']

# %%
# More adding examples
tasks = ["read", "practice"]

tasks.append("submit")
tasks.insert(0, "login")
tasks.extend(["review", "reflect"])

print(tasks)

# %% [markdown]
# ## 13. Removing Items from a List
#
# Common methods for removing items:
#
# | Method | Description |
# |--------|-------------|
# | `.remove(value)` | Remove a specific value |
# | `.pop(index)` | Remove an item by index and return it |
# | `.clear()` | Remove all items |

# %%
fruits = ["apple", "banana", "orange", "mango"]

fruits.remove("banana")
print(fruits)

removed_item = fruits.pop(1)
print(f"Removed item: {removed_item}")
print(fruits)

fruits.clear()
print(fruits)

# %%
# More removing examples
tasks = ["login", "read", "practice", "submit", "review"]

tasks.remove("read")
print(tasks)

last_task = tasks.pop()
print(last_task)
print(tasks)

del tasks[0]
print(tasks)
# Out:
# ['login', 'practice', 'submit', 'review']
# review
# ['login', 'practice', 'submit']
# ['practice', 'submit']

# %% [markdown]
# ## 14. Useful List Functions and Methods
#
# | Function or Method | Description |
# |--------------------|-------------|
# | `len(list)` | Count the number of items |
# | `sum(list)` | Add all numeric items |
# | `min(list)` | Get the smallest value |
# | `max(list)` | Get the largest value |
# | `.sort()` | Sort the list in place |
# | `.reverse()` | Reverse the list in place |

# %%
scores = [80, 75, 92, 88, 60]

print(len(scores))
print(sum(scores))
print(min(scores))
print(max(scores))
print(sum(scores) / len(scores))

scores.sort()
print(scores)

scores.reverse()
print(scores)

# %%
# More list function examples
values = [12, 5, 30, 18, 7]

print("Sorted copy:", sorted(values))
print("Original list:", values)
print("Largest three values:", sorted(values, reverse=True)[:3])
print("Count of 5:", values.count(5))

# %% [markdown]
# ## 15. 2D Lists
#
# A **2D list** is a list inside another list. It is useful for storing table-like data, such as rows and columns.
#
# Example structure:
#
# ```python
# table = [
#     [row_1_column_1, row_1_column_2],
#     [row_2_column_1, row_2_column_2]
# ]
# ```

# %%
# Creating a 2D list
students = [
    ["Alice", 85],
    ["Bob", 72],
    ["Charlie", 90]
]

print(students)
print(students[0])     # First row
print(students[0][0])  # First row, first column
print(students[0][1])  # First row, second column
# Out:
# [['Alice', 85], ['Bob', 72], ['Charlie', 90]]
# ['Alice', 85]
# Alice
# 85

# %% [markdown]
# ### Accessing Rows and Columns
#
# Use two indexes to access a value inside a 2D list:
#
# ```python
# list_name[row_index][column_index]
# ```
#
# The first index selects the row. The second index selects the item inside that row.

# %%
# Accessing values in a 2D list
sales = [
    ["Jan", 12000, 9000],
    ["Feb", 15000, 11000],
    ["Mar", 18000, 14000]
]

print(sales[0][0])  # Month in row 0
print(sales[1][1])  # Revenue in row 1
print(sales[2][2])  # Cost in row 2
# Out:
# Jan
# 15000
# 14000

# %% [markdown]
# ### Updating Values in a 2D List
#
# Because lists are mutable, you can update values inside a 2D list by using row and column indexes.

# %%
# Updating a value in a 2D list
sales = [
    ["Jan", 12000, 9000],
    ["Feb", 15000, 11000],
    ["Mar", 18000, 14000]
]

sales[1][1] = 16000

print(sales)
print(sales[1])

# %% [markdown]
# ### 2D List Example Without Loops
#
# You can calculate values from a small 2D list by accessing each row directly.

# %%
# Calculate total revenue without using a loop
sales = [
    ["Jan", 12000, 9000],
    ["Feb", 15000, 11000],
    ["Mar", 18000, 14000]
]

total_revenue = sales[0][1] + sales[1][1] + sales[2][1]
total_cost = sales[0][2] + sales[1][2] + sales[2][2]
profit = total_revenue - total_cost

print(f"Total revenue: {total_revenue}")
print(f"Total cost: {total_cost}")
print(f"Profit: {profit}")
# Out:
# Total revenue: 45000
# Total cost: 34000
# Profit: 11000

# %% [markdown]
# ## 16. Splitting and Joining Strings
#
# `split()` converts a string into a list.
#
# `join()` combines list items into one string.

# %%
sentence = "Python is easy to learn"
words = sentence.split()

print(words)

new_sentence = "-".join(words)
print(new_sentence)
# Out:
# ['Python', 'is', 'easy', 'to', 'learn']
# Python-is-easy-to-learn

# %% [markdown]
# ### More `split()` Examples
#
# The `split()` function can separate text by spaces, commas, symbols, or a limited number of breaks.

# %%
# split() with spaces
sentence = "Python is easy to learn"
print(sentence.split())

# split() with comma
product_text = "apple,banana,orange"
print(product_text.split(","))

# split() with a custom symbol
student_record = "Alice|BI303|90"
print(student_record.split("|"))
# Out:
# ['Python', 'is', 'easy', 'to', 'learn']
# ['apple', 'banana', 'orange']
# ['Alice', 'BI303', '90']

# %%
# split() with maxsplit
full_name = "John Michael Smith"
print(full_name.split(" ", 1))   # Split only once
print(full_name.split(" ", 2))   # Split two times

# split() together with strip()
raw_tags = " python, sql, dashboard "
tags = raw_tags.strip().split(", ")
print(tags)
# Out:
# ['John', 'Michael Smith']
# ['John', 'Michael', 'Smith']
# ['python', 'sql', 'dashboard']

# %% [markdown]
# ## Practice Exercise 3
#
# Create a list called `favorite_foods` with at least 3 foods.
#
# Then:
# - Print the full list
# - Print the first food
# - Add one more food to the list
# - Print the updated list

# %%
# TODO: Write your answer here
favorite_foods = ["Buldak", "Salmon", "Cheese"]
print(favorite_foods[0])
favorite_foods.append("KFC")
print(favorite_foods)
# Out:
# Buldak
# ['Buldak', 'Salmon', 'Cheese', 'KFC']

# %% [markdown]
# ## Practice Exercise 4
#
# Given the list of scores below, calculate and print:
# - The number of scores
# - The highest score
# - The lowest score
# - The average score

# %%
scores = [78, 85, 90, 66, 72]
print(len(scores))
print(max(scores))
print(min(scores))
print(sum(scores) / len(scores))
# TODO: Write your answer here
# Out:
# 5
# 90
# 66
# 78.2

# %% [markdown]
# ## Practice Exercise 5
#
# Use the 2D list below. Do **not** use a loop.
#
# Print:
# - The first row
# - The name `Mango`
# - The price `25`
# - The stock value `40`

# %%
products = [
    ["Apple", 20, 50],
    ["Mango", 25, 40],
    ["Orange", 15, 60]
]
print(products[0])
print("The name", products[1][0])
print("The price", products[1][1])
print("The stock value", products[1][2])
# TODO: Write your answer here without using a loop
# Out:
# ['Apple', 20, 50]
# The name Mango
# The price 25
# The stock value 40

# %% [markdown]
# ## Practice Exercise 6
#
# Use the 2D list below. Do **not** use a loop.
#
# Calculate and print:
# - Total sales for January, February, and March
# - Total expenses for January, February, and March
# - Total profit

# %%
monthly_data = [
    ["Jan", 12000, 8000],
    ["Feb", 15000, 9500],
    ["Mar", 18000, 11000]
]
Total_sales = monthly_data[0][1] + monthly_data[1][1] + monthly_data[2][1]
Total_expenses = monthly_data[0][2] + monthly_data[1][2] + monthly_data[2][2]
Profit = Total_sales - Total_expenses
print(Total_sales)
print(Total_expenses)
print(Profit)

# TODO: Write your answer here without using a loop
# Out:
# 45000
# 28500
# 16500

# %% [markdown]
# ## Practice Exercise 7
#
# Use the lists below. Do **not** use a loop.
#
# Print:
# - The number of scores
# - The highest score
# - The lowest score
# - The average score
# - The first three scores

# %%
scores = [78, 85, 90, 66, 72]

print(len(scores))
print(max(scores))
print(min(scores))
print(sum(scores) / len(scores))
print(scores[0:3])
# TODO: Write your answer here without using a loop
# Out:
# 5
# 90
# 66
# 78.2
# [78, 85, 90]

# %% [markdown]
# ## Summary
#
# In this notebook, you learned that:
#
# - Strings are used for text data.
# - Lists are used to store multiple values.
# - 2D lists are useful for table-like data with rows and columns.
# - Indexing starts at `0` in Python.
# - Slicing lets you select part of a string or list.
# - String and list methods help you transform and manage data.
